# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("cleaned_Review_dataset.csv")
df.head()
# Out:
#    review_id  product_id  rating  review_time                summary  \
# 0          1  B001E4KFG0       5   1303862400  Good Quality Dog Food
# 1          2  B00813GRG4       1   1346976000      Not as Advertised
# 2          3  B000LQOCH0       4   1219017600  "Delight" says it all
# 3          4  B000UA0QIQ       2   1307923200         Cough Medicine
# 4          5  B006K2ZZ7K       5   1350777600            Great taffy
#
#                                          review_text review_date sentiment
# 0  I have bought several of the Vitality canned d...  2011-04-27  Positive
# 1  Product arrived labeled as Jumbo Salted Peanut...  2012-09-07  Negative
# 2  This is a confection that has been around a fe...  2008-08-18  Positive
# 3  If you are looking for the secret ingredient i...  2011-06-13  Negative
# 4  Great taffy at a great price.  There was a wid...  2012-10-21  Positive

# %%
#Rating distribution
plt.figure(figsize=(8,5))
sns.countplot(x='rating', data=df)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Reviews")
plt.show()

# %% [markdown]
# Insight:
# Most customers gave high ratings, which shows overall positive customer satisfaction.

# %%
#Sentiment distribution
plt.figure(figsize=(8,5))
sns.countplot(x='sentiment', data=df)
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()

# %% [markdown]
# Insight:
# Positive reviews are higher than negative reviews, but negative reviews are important because they reveal business problems.

# %%
#Top 10 products by review count
top_products = df['product_id'].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_products.index, y=top_products.values)
plt.title("Top 10 Products by Review Count")
plt.xlabel("Product ID")
plt.ylabel("Number of Reviews")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight:
# Some products receive significantly more reviews, indicating higher customer engagement or sales volume.

# %%
#Average rating
df['rating'].mean()
# Out:
# np.float64(4.183198640523243)

# %% [markdown]
# Insight:
# Average rating helps understand overall customer satisfaction level.

# %%
#Create Review length :   Har review me kitne characters hain wo calculate hota hai
df['review_length'] = df['review_text'].apply(len)
